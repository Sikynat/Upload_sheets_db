# %%
# importar as dependencias
import pandas as pd

# %%
# Ler o arquivo de excel

df = pd.read_excel(r'data/table-price-today.xlsx', usecols=['CÓDIGO', 'DESCRIÇÃO', 'GRUPO', 'TABELA'])

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 # Ler o arquivo de excel
# ----> 3 df = pd.read_excel(r'data/table-price-today.xlsx', usecols=['CÓDIGO', 'DESCRIÇÃO', 'GRUPO', 'TABELA'])
#       5 df
#
# NameError: name 'pd' is not defined

# %%
df.groupby('TABELA').max().reset_index()
# Out:
#            TABELA  CÓDIGO                                          DESCRIÇÃO  \
# 0            5.95  MA1001           COLA PROFISSIONAL T7000 PRETA 15ML WEFIX
# 1            6.12   M2279                              TOUCH ON 7 DOURADO NN
# 2            6.47   M2271                                  TOUCH 532 ROSA NN
# 3            7.96   C3009                 E6PLUS CONECTOR DE CARGA POWER ORG
# 4               9   C6079  REDMINOTE105G - POCO M3PRO CONECTOR DE CARGA P...
# ...           ...     ...                                                ...
# 1858      2001.05   W2360               S25ULTRA PRETO C/ ARO NACIONAL WEFIX
# 1859      2018.46   W1076      16PRO PRETO S/ ARO AMOLED COMPATIVEL IC WEFIX
# 1860      2324.33   W1074   15PROMAX PRETO S/ ARO AMOLED COMPATIVEL IC WEFIX
# 1861      5998.35   M2073   MAQUINA DE TESTE M830 ( VEM 250 FLEX, 1 TOMADA )
# 1862  SEM ESTOQUE   W7031          realme C67 4G-REALME 125G PRETO S/ ARO NN
#
#                   GRUPO
# ...

# %%
colunas = df.columns.values
tuples = [tuple(x) for x in [df[coluna].values for coluna in colunas]]

print(tuples)
# Out:
# [('W1001', 'W1002', 'W1006', 'W1010', 'W1011', 'W1012', 'W1018', 'W1022', 'W1025', 'W1026', 'W1028', 'W1029', 'W1030', 'W1031', 'W1032', 'W1033', 'W1034', 'W1035', 'W1036', 'W1037', 'W1038', 'W1039', 'W1040', 'W1041', 'W1042', 'W1043', 'W1044', 'W1045', 'W1047', 'W1048', 'W1050', 'W1052', 'W1053', 'W1063', 'W1064', 'W1066', 'W1072', 'W1073', 'W1074', 'W1075', 'W1076', 'W1078', 'W1079', 'W1080', 'W1081', 'W1082', 'W1083', 'W1084', 'W1085', 'W1086', 'W1087', 'W1088', 'W14001', 'W14002', 'W14003', 'W14004', 'W14005', 'W14006', 'W14007', 'W14008', 'W14009', 'W14010', 'W14011', 'W14012', 'W14013', 'W14014', 'W14015', 'W14016', 'W14017', 'W4000', 'W4001', 'W4002', 'W4003', 'W4004', 'W4005', 'W4006', 'W4007', 'W4008', 'W4009', 'W4010', 'W4011', 'W4012', 'W4013', 'W4016', 'W4017', 'W4018', 'W4019', 'W4020', 'W2109', 'W3000', 'W3001', 'W3002', 'W3003', 'W3004', 'W3005', 'W3007', 'W3008', 'W3009', 'W3010', 'W3011', 'W3013', 'W3014', 'W3015', 'W3016', 'W3017', 'W3018', 'W3019', 'W3020', 'W3021'
# ...
