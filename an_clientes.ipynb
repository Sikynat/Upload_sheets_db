# %%
import pandas as pd

# %%
df = pd.read_excel(r'upClientes/tabela_clientes.xlsx', usecols=['Nome', 'Endereço', 'Frete', 'Nota', 'Código Wefix', 'Status', 'UF', 'Município', 'Contato'])
df

styler = df.style
styler.set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'left')]}
])

df.style.set_properties(**{'text-align': 'left'} )
# Out:
# <style type="text/css">
# ...

# %%
df = pd.read_excel(r'upClientes/tabela_clientes.xlsx', usecols=['Status', 'Código Wefix', 'Nome', 'Endereço', 'UF', 'Município', 'Nota', 'Frete'])
df

styler = df.style
styler.set_table_styles([
    {'selector': 'th', 'props': [('text-align', 'left')]}
])

df.style.set_properties(**{'text-align': 'left'} )
# Out:
# <style type="text/css">
# ...
